# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Read CSV file
df = pd.read_csv('new_keyword_dataset.csv')
print("Initial DataFrame head:")
print(df.head())

# Fill missing search volume with 0, convert to numeric
df['Avg. monthly searches'] = pd.to_numeric(df['Avg. monthly searches'], errors='coerce').fillna(0)
df.dropna(subset=['Keyword'], inplace=True)
print(f"Total rows after cleaning: {len(df)}")

# Vectorize keywords and cluster (using full dataset)
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Keyword'])
kmeans = KMeans(n_clusters=4, random_state=42)
df.loc[:, 'Cluster'] = kmeans.fit_predict(X)

# Define intent function
def assign_intent(keyword):
    keyword = keyword.lower()
    if 'what is' in keyword or 'vs' in keyword or 'programming' in keyword:
        return 'Informational'
    elif 'tools' in keyword or 'test' in keyword or 'testing' in keyword or 'deploy' in keyword or 'automation' in keyword:
        return 'Transactional'
    elif 'best' in keyword or ('software' in keyword and 'tools' not in keyword):
        return 'Commercial'
    else:
        return 'Navigational'

# Remove duplicates and assign intent
df = df.drop_duplicates(subset=['Keyword'])
df.loc[:, 'Intent'] = df['Keyword'].apply(assign_intent)

# Save full dataset with all columns
df.to_csv('new_clustered_keywords.csv', index=False)
print(f"Saved to 'new_clustered_keywords.csv' with {len(df.columns)} columns.")
# Out:
# Initial DataFrame head:
#                        Keyword Region  Avg. monthly searches Growth  \
# 0                    build app    USA                 5000.0     0%
# 1  website and app development    USA                 5000.0     0%
# 2                   app tester    USA                 5000.0     0%
# 3          no code app builder    USA                 5000.0     0%
# 4             best app builder    USA                 5000.0   -90%
#
#   Competition  Competition (indexed value)  Top of page bid (low range)  \
# 0      Medium                         41.0                         2.94
# 1         Low                         10.0                         6.07
# 2         Low                         24.0                         2.47
# 3      Medium                         42.0                         3.89
# 4      Medium                         49.0                         3.51
#
#    Top of page bid (high range) Start Date   End Date
# 0                         12.10   3/1/2024  2/28/2025
# 1                         40.60   3/1/2024  2/28/2025
# 2                         15.24   3/1/2024  2/28/2025
# 3                         15.86   3/1/2024  2/28/2025
# 4                         15.64   3/1/2024  2/28/2025
# Total rows after cleaning: 204
# Saved to 'new_clustered_keywords.csv' with 12 columns.

# %%
# Group by cluster, get top 10 by Avg. monthly searches, and save to CSV
top_10_per_cluster = pd.concat(
    [group.sort_values('Avg. monthly searches', ascending=False).head(10) 
     for _, group in df.groupby('Cluster')]
)

# Print for verification
for cluster, group in top_10_per_cluster.groupby('Cluster'):
    print(f"\nCluster {cluster} (Top 10 by Avg. monthly searches):")
    print(group)

# Save to CSV with all columns
top_10_per_cluster.to_csv('top_10_per_cluster.csv', index=False)
print(f"Saved top 10 keywords per cluster to 'top_10_per_cluster.csv' with {len(top_10_per_cluster.columns)} columns.")
# Out:
# Cluster 0 (Top 10 by Avg. monthly searches):
#                                       Keyword Region  Avg. monthly searches  \
# 171                      backend optimization    USA                50000.0
# 134                     openapi specification    USA                50000.0
# 138  backend developer vs front end developer    USA                 5000.0
# 135                            fastapi python    USA                 5000.0
# 141            front end vs backend developer    USA                 5000.0
# 142               front vs back end developer    USA                 5000.0
# 140            front end developer vs backend    USA                 5000.0
# 89                 Automated error correction    USA                  500.0
# 137          backend and frontend programming    USA                  500.0
# 113               Code generation for backend    USA                  500.0
#
#     Growth Competition  Competition (indexed value)  \
# 171     0%         Low                         17.0
# 134     0%         Low                          1.0
# 138     0%         Low                          1.0
# 135     0%         Low                          1.0
# 141     0%         Low                          1.0
# 142     0%         Low                          1.0
# 140     0%         Low                          0.0
# 89      0%      Medium                         14.0
# 137     0%         Low                          9.0
# 113     0%      Medium                         18.0
#
#      Top of page bid (low range)  Top of page bid (high range) Start Date  \
# 171                         2.00                          5.00   3/1/2024
# 134                         3.07                         16.70   3/1/2024
# 138                         0.23                         10.01   3/1/2024
# 135                         0.67                          8.84   3/1/2024
# 141                         0.23                         10.01   3/1/2024
# 142                         0.23                         10.01   3/1/2024
# 140                         0.23                          5.08   3/1/2024
# 89                          3.85                          9.30   3/1/2024
# 137                         3.16                         13.40   3/1/2024
# 113                         3.00                          6.01   3/1/2024
#
#       End Date  Cluster         Intent
# 171  2/28/2025        0   Navigational
# 134  2/28/2025        0   Navigational
# 138  2/28/2025        0  Informational
# 135  2/28/2025        0   Navigational
# 141  2/28/2025        0  Informational
# 142  2/28/2025        0  Informational
# 140  2/28/2025        0  Informational
# 89   2/28/2025        0   Navigational
# 137  2/28/2025        0  Informational
# 113  2/28/2025        0   Navigational
#
# Cluster 1 (Top 10 by Avg. monthly searches):
#                  Keyword Region  Avg. monthly searches Growth Competition  \
# 159  developer api tools    USA               500000.0     0%         Low
# 126             open api    USA                50000.0     0%         Low
# 118             rest api    USA                50000.0     0%         Low
# 16           test an api    USA                 5000.0     0%         Low
# 131              api key    USA                 5000.0     0%         Low
# 130          graphql api    USA                 5000.0     0%         Low
# 129          swagger api    USA                 5000.0     0%         Low
# 128       api management    USA                 5000.0     0%         Low
# 127    api documentation    USA                 5000.0     0%         Low
# 125             mock api    USA                 5000.0     0%         Low
#
#      Competition (indexed value)  Top of page bid (low range)  \
# 159                         30.0                         2.51
# 126                          1.0                         3.07
# 118                          1.0                         1.03
# 16                          19.0                         2.98
# 131                          9.0                         2.37
# 130                          4.0                         1.29
# 129                         12.0                         1.98
# 128                         27.0                         9.78
# 127                          8.0                         2.68
# 125                         20.0                         3.68
#
#      Top of page bid (high range) Start Date   End Date  Cluster  \
# 159                          8.13   3/1/2024  2/28/2025        1
# 126                         16.70   3/1/2024  2/28/2025        1
# 118                         11.15   3/1/2024  2/28/2025        1
# 16                           8.05   3/1/2024  2/28/2025        1
# 131                          9.51   3/1/2024  2/28/2025        1
# 130                          7.99   3/1/2024  2/28/2025        1
# 129                         13.87   3/1/2024  2/28/2025        1
# 128                         25.22   3/1/2024  2/28/2025        1
# 127                         10.43   3/1/2024  2/28/2025        1
# 125                         10.81   3/1/2024  2/28/2025        1
#
#             Intent
# 159  Transactional
# 126   Navigational
# 118   Navigational
# 16   Transactional
# 131   Navigational
# 130   Navigational
# 129   Navigational
# 128   Navigational
# 127   Navigational
# 125   Navigational
#
# Cluster 2 (Top 10 by Avg. monthly searches):
#                                  Keyword Region  Avg. monthly searches Growth  \
# 0                              build app    USA                 5000.0     0%
# 136      backend vs frontend development    USA                 5000.0     0%
# 99                AI-powered API testing    USA                 5000.0     0%
# 79            AI-powered code generation    USA                 5000.0     0%
# 139  backend vs frontend web development    USA                 5000.0     0%
# 1            website and app development    USA                 5000.0     0%
# 148                  backend development    USA                 5000.0     0%
# 163             fast backend development    USA                 5000.0     0%
# 119                      api development    USA                 5000.0     0%
# 6               app development services    USA                 5000.0   900%
#
#     Competition  Competition (indexed value)  Top of page bid (low range)  \
# 0        Medium                         41.0                         2.94
# 136         Low                          0.0                         0.23
# 99         High                         25.0                         3.69
# 79         High                         34.0                         3.25
# 139         Low                          0.0                         0.23
# 1           Low                         10.0                         6.07
# 148         Low                          6.0                         2.01
# 163         Low                         24.0                         6.24
# 119         Low                         22.0                         3.92
# 6           Low                          5.0                        17.85
#
#      Top of page bid (high range) Start Date   End Date  Cluster  \
# 0                           12.10   3/1/2024  2/28/2025        2
# 136                          5.08   3/1/2024  2/28/2025        2
# 99                          10.79   3/1/2024  2/28/2025        2
# 79                          15.03   3/1/2024  2/28/2025        2
# 139                          5.08   3/1/2024  2/28/2025        2
# 1                           40.60   3/1/2024  2/28/2025        2
# 148                          6.44   3/1/2024  2/28/2025        2
# 163                         24.29   3/1/2024  2/28/2025        2
# 119                         19.06   3/1/2024  2/28/2025        2
# 6                           65.14   3/1/2024  2/28/2025        2
#
#             Intent
# 0     Navigational
# 136  Informational
# 99   Transactional
# 79    Navigational
# 139  Informational
# 1     Navigational
# 148   Navigational
# 163   Navigational
# 119   Navigational
# 6     Navigational
#
# Cluster 3 (Top 10 by Avg. monthly searches):
#                            Keyword Region  Avg. monthly searches Growth  \
# 69          postgresql integration    USA                50000.0   900%
# 124                api integration    USA                 5000.0     0%
# 23         api integration testing    USA                  500.0   -90%
# 70          sql server integration    USA                  500.0     0%
# 90            Database integration    USA                  500.0     0%
# 92              GitHub integration    USA                  500.0     0%
# 114        API integration testing    USA                  500.0     0%
# 172     continuous integration api    USA                  500.0     0%
# 44   api integration testing tools    USA                   50.0     0%
# 74        data integration systems    USA                   50.0     0%
#
#     Competition  Competition (indexed value)  Top of page bid (low range)  \
# 69          Low                          NaN                         1.00
# 124         Low                        23.00                         4.95
# 23          Low                        14.00                         3.88
# 70          Low                         2.43                         1.00
# 90       Medium                        11.00                         2.13
# 92       Medium                        30.00                         2.44
# 114      Medium                        19.00                         4.00
# 172         Low                         2.00                         3.65
# 44          Low                        26.00                         2.17
# 74          Low                         6.83                        10.00
#
#      Top of page bid (high range) Start Date   End Date  Cluster  \
# 69                            NaN   3/1/2024  2/28/2025        3
# 124                         17.53   3/1/2024  2/28/2025        3
# 23                          12.21   3/1/2024  2/28/2025        3
# 70                           8.36   3/1/2024  2/28/2025        3
# 90                          11.78   3/1/2024  2/28/2025        3
# 92                           9.71   3/1/2024  2/28/2025        3
# 114                          7.90   3/1/2024  2/28/2025        3
# 172                         18.76   3/1/2024  2/28/2025        3
# 44                          13.94   3/1/2024  2/28/2025        3
# 74                          25.00   3/1/2024  2/28/2025        3
#
#             Intent
# 69    Navigational
# 124   Navigational
# 23   Transactional
# 70    Navigational
# 90    Navigational
# 92    Navigational
# 114  Transactional
# 172   Navigational
# 44   Transactional
# 74    Navigational
# Saved top 10 keywords per cluster to 'top_10_per_cluster.csv' with 12 columns.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
